# %%
import numpy as np
from numpy import ndarray
import pandas as pd
from pandas import DataFrame

scores:ndarray | None = None # 學生的分數
scores_df:DataFrame | None = None # 學生分數的DataFrame

scores = np.random.randint(40 ,101, size=(50,5))
#print(type(scores))
#print(scores.shape)
#scores
scores_df= pd.DataFrame(scores,
            index=range(1,51),
            columns=['國文','英文','數學','地理','歷史'])
#scores_df.T #樞紐分析
names_df:DataFrame = pd.read_csv('students.csv')
scores_df[['姓名','性別']]= names_df[['姓名','性別']].head(n=50).values
scores_df = scores_df[['姓名','性別','國文','英文','數學','地理','歷史']]
#選取欄
scores_df[['姓名','國文']]
#選取列
scores_df.iloc[5]
scores_df.iloc[5:10]
# Out:
#      姓名 性別  國文  英文  數學  地理  歷史
# 6   朱冠霖  男  54  55  61  44  75
# 7   謝欣蓉  女  47  73  75  47  60
# 8   羅淑芬  女  86  71  80  82  46
# 9   許美慧  女  55  78  54  68  64
# 10  廖志豪  男  59  44  56  47  53

# %%
scores_df[scores_df['姓名'] == '許美慧']
scores_df[scores_df['國文'] < 60]
scores_df.query("性別 == '女' and 國文 < 60")
# Out:
#      姓名 性別  國文  英文  數學  地理  歷史
# 7   謝欣蓉  女  47  73  75  47  60
# 9   許美慧  女  55  78  54  68  64
# 13  蘇雅婷  女  40  68  87  74  79
# 19  呂婉慧  女  42  56  92  96  68
# 27  江雅琪  女  57  76  75  73  74
# 29  簡婉慧  女  55  56  67  86  72
# 48  劉婉婷  女  59  76  41  80  69

# %%
scores_df["總分"] = scores_df[['國文', '英文', '數學', '地理', '歷史']].sum(axis=1)
scores_df["平均"] = scores_df[['國文', '英文', '數學', '地理', '歷史']].mean(axis=1)
scores_df["排名"] = scores_df["總分"].rank(ascending=False,method='min')
scores_df.sort_values(by='排名')
# Out:
#      姓名 性別   國文  英文   數學  地理  歷史   總分    平均    排名
# 39  彭美慧  女   82  92   97  71  98  440  88.0   1.0
# 35  劉浩然  男   91  83   54  93  96  417  83.4   2.0
# 34  簡建宏  男   97  90   69  63  90  409  81.8   3.0
# 18  王冠廷  男   87  93   96  72  60  408  81.6   4.0
# 40  劉靜芬  女   82  83   98  71  72  406  81.2   5.0
# 32  蕭怡伶  女   84  66   93  70  91  404  80.8   6.0
# 15  王婉茹  女   61  85   80  87  86  399  79.8   7.0
# 1   劉彥宏  男   57  99   92  88  57  393  78.6   8.0
# 3   吳子睿  男   62  90   85  84  67  388  77.6   9.0
# 12  呂承恩  男   94  75   75  68  72  384  76.8  10.0
# 30  楊靜宜  女   69  89  100  63  62  383  76.6  11.0
# 25  洪怡君  女   70  84   84  70  74  382  76.4  12.0
# 20  莊子謙  男   90  44   97  63  87  381  76.2  13.0
