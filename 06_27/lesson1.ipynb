# %%
a = [1, 2, 3]
print(a + [4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
import numpy as np

b = np.array([1, 2, 3])
print(b + np.array([4, 5, 6]))
# Out:
# [5 7 9]

# %%
import numpy as np

arr1 = np.array([6, 7.5, 8, 0, 1])
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
arr2 = arr1 * 5
arr2
# Out:
# array([30. , 37.5, 40. ,  0. ,  5. ])

# %%
arr3 = arr1 / 10
arr3
# Out:
# array([0.6 , 0.75, 0.8 , 0.  , 0.1 ])
